# %%
import pandas as pd

# %%
stats = pd.read_csv('/Users/danilo/Documents/python-for-data-science/Data Frames/P4-Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.columns = ['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']= 10,4
import warnings
warnings.filterwarnings('ignore')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# Distribution
visl = sns.distplot(stats["InternetUsers"])

# %%
visl = sns.distplot(stats["InternetUsers"], bins=30)

# %%
#Boxplots:
vis2 = sns.boxplot(data=stats, x="IncomeGroup", y="BirthRate")

# %%
#Seaborn Gallery in Google
#Happy Coding Danilo

# %%
vis3 = sns.lmplot(x='InternetUsers',y='BirthRate',data=stats)

# %%
vis3 = sns.lmplot(x='InternetUsers',y='BirthRate',data=stats, fit_reg=False)

# %%
vis3 = sns.lmplot(x='InternetUsers',y='BirthRate'\
                  ,data=stats, fit_reg=False, hue='IncomeGroup', size=10)

# %% [markdown]
# # Keyword Arguments in Python

# %%
# Marker Size
vis3 = sns.lmplot(x='InternetUsers',y='BirthRate',data=stats, \
                  fit_reg=False, hue='IncomeGroup', size=8,   \
                  scatter_kws={"s":100})

# %%
#Happy Coding Danilo
