# %% [markdown]
# ## Índice
#
# 1. Importando Bibliotecas
# 2. O que é um tipo de dados de categoria
# 3. Alterando a categoria
# 4. Trabalhando com JointPlots
# 5. Histogramas
# 6. Histogramas Empilhados
# 7. Criando um KDE Plot
# 8. Trabalhando com Subplots()
# 9. Violinplots vs Boxplots
# 10. Creating a Facet Grid

# %% [markdown]
# ### O QUE É UM TIPO DE DADOS DE CATEGORIA

# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\danil\\Documents\\Python Programming Course\\Data Frames\\Visualização Avançada'

# %%
movies = pd.read_csv('Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %% [markdown]
# ---

# %% [markdown]
# ### ALTERANDO A CATEGORIA

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
# Happy Coding

# %% [markdown]
# ---

# %% [markdown]
# ### TRABALHANDO COM JOINTPLOTS

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'hex', size = 7)

# %% [markdown]
# ---

# %% [markdown]
# ### HISTOGRAMAS

# %%
vis1 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
sns.set_style('darkgrid')
vis2 = sns.distplot(movies.CriticRating, bins = 15)

# %%
sns.set_style('white')
n1 = plt.hist(movies.AudienceRating, bins=15)

# %%
n2 = plt.hist(movies.CriticRating, bins=15)

# %% [markdown]
# ----

# %% [markdown]
# ### HISTOGRAMAS EMPILHADOS

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 15)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions, \
         movies[movies.Genre == 'Drama'].BudgetMillions, \
         movies[movies.Genre == 'Thriller'].BudgetMillions, \
         movies[movies.Genre == 'Comedy'].BudgetMillions], \
         bins=15, stacked=True)
plt.show()

# %% [markdown]
# ### Usando Loop For para Empilhar Todos os Gêneros

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = list()
mylabels = list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)
h = plt.hist(list1, bins = 30, stacked=True, rwidth=1, label = mylabels)
plt.legend()
plt.show()

# %%
# Happy Coding

# %% [markdown]
# ### Criando um KDE Plot

# %%
vis3 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', \
                  fit_reg=False, hue='Genre',\
                  size=6, aspect=1)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, \
                 shade=True, shede_lowest=False, cmap='Reds')

# %%
# Happy Coding

# %% [markdown]
# ### Trabalhando com Subplots( )

# %%
sns.set_style('dark')
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
f, ax = plt.subplots(1,2, figsize = (12,6))

# %%
k4 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)
k5 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
fig, axes = plt.subplots(1,2, figsize = (14,7), sharey=True)
k4 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axes[0])
k5 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])
k4.set(xlim=(-50, 250))
k5.set(xlim=(-50, 250))
# Out:
# [(-50.0, 250.0)]

# %%
axes
# Out:
# array([<AxesSubplot:xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <AxesSubplot:xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
# Happy Coding

# %% [markdown]
# ### Violinplots vs Boxplots

# %%
z = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
w = sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
z1 = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating')

# %%
z1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y='CriticRating')

# %%
# Happy Coding

# %% [markdown]
# ### Creating a Facet Grid

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter.CriticRating, movies.AudienceRating)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9892/2403178725.py in <module>
#       1 g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
# ----> 2 g = g.map(plt.scatter.CriticRating, movies.AudienceRating)
#
# AttributeError: 'function' object has no attribute 'CriticRating'

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
g = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
#Happy Coding Danilo
